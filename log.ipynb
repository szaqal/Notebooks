# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
x = np.arange(1, 1000, 10)
plt.grid(True)
plt.plot(x,np.log2(x), color="red", label="Graph")

# %%
x = np.arange(1, 10.1, 0.1)
plt.grid(True)
plt.plot(x,np.power(2,x), color="red", label="Graph")
